# %% [markdown]
# #Homework 8 (10 pt)
# <font color=red>**Danger zone:**</font> you'll be fine-tuning a model to generate positive, negative or even toxic reviews. We'll be doing this for fun, but this is also the technique for [review bombing](https://en.wikipedia.org/wiki/Review_bomb), bot farms on social media and other less than dignified stuff. It is ultimately your decision how you apply this knowledge, but before you choose, ask yourself: is this why you chose to learn ML?
#
#
# # LLMs Alignment with Reinforcement Learning from human feedback (RLHF).
#
# _based on the [notebook](https://github.com/yandexdataschool/nlp_course/blob/2024/week08_rlhf/practice.ipynb) based the [original notebook](https://github.com/antndlcrx/oxford-llms-workshop/blob/main/materials/seminars/day_3/8_LLMs%20alignment%20with%20RLHF.ipynb) by Ilya Boytsov for the Oxford LLMs workshop_

# %% [markdown]
# In this session, you're gonna fine-tune a language model with reinforcement learning to make it generate good (or bad) reviews.
#
# To perform RL-based fine-tuning, we'll use a new (in this course) library called [Transformer Reinforcement Learning (TRL)](https://huggingface.co/docs/trl). TRL implements the main reinforcement learning components of RLHF: reward modeling and fine-tuning with PPO.
#
# ![img](https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/TRL-readme.png)

# %%
# !pip install --quiet --upgrade transformers trl peft
#datasets-3.4.1 peft-0.15.0 transformers-4.50.1 trl-0.16.0 xxhash-3.5.0
# In the original notebook
# %pip install -q trl==0.7.4 transformers==4.33.1 datasets==2.14.4 peft==0.5.0
# Out:
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the '/users/u29/bobbyd/RIT_LLM/.venv/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ### Tutorial: align the model to generate positive movie reviews
#
# To see how TRL works, we'll use it to align GPT2 on IMDB dataset to generate positive (or negative) movie reviews. In fact, __it's your choice whether you want positive or negative reviews.__
#
# But before you choose, let's take a look at the baseline model: a GPT-2 fine-tuned on generating arbitrary movie reviews.

# %%
import torch
import transformers
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
main_tokenizer = transformers.AutoTokenizer.from_pretrained("lvwerra/gpt2-imdb")
main_model = transformers.AutoModelForCausalLM.from_pretrained("lvwerra/gpt2-imdb", device_map=device)

# %%
inputs = main_tokenizer("The movie", return_tensors='pt').to(device)
generated_ids = main_model.generate(**inputs, max_new_tokens=50, do_sample=True)
print("\nGenerated text:", main_tokenizer.decode(generated_ids.flatten().cpu().numpy().tolist()))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated text: The movie was about as exciting as ever from what I was hoping they made with the movie. I have to say, it was an excellent movie and I loved it too! And, by the way, did David Aitken go ahead and make this in

# %% [markdown]
# If you run this cell a couple of times, you'll see that the model generates both positive, negative and neutral reviews in some proportion. What we're gonna do next is teach the model to generate more positive (or negative) reviews.
#
# Similarly to InstructGPT, we're gonna do that in 2 stages:
# - **train a reward model** to assign higher values to positive (or negative) reviews
# - fine-tune the language model to **maximize that reward using [proximal policy optimization](https://openai.com/research/openai-baselines-ppo)**

# %% [markdown]
# ## Stage 1: train a reward model (2 points)
#
# First, we'll train a BERT-like model as our reward model. We'll generate a synthetic pairwise rankings to emulate human rankings.
#
# __Q:__ why do I need a reward model? Can I just use a pre-trained sentiment classifier? <br> __A:__ Yes, you can - but that only works for movie reviews. But this tutorial will teach you how to do RLHF for any kind objective.
#
#
# __If you actually want to maximize sentiment (or other "label") instead of human preferences, train reward model as a classifier! (see week5)__

# %%
# We'll be fine-tuning a small BERT-like model for now. Please try other models for the main assignment.
reward_model = transformers.AutoModelForSequenceClassification.from_pretrained("distilbert-base-cased", device_map=device)
reward_tokenizer = transformers.AutoTokenizer.from_pretrained("distilbert-base-cased")
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# __Note that__ the reward model has a separate tokenizer, different from the main model. They don't need to be the same for RLHF fine-tuning.

# %%
# To train a reward model, you need a dataset (or generator) of positive-negative pairs.
# Each training sample should be a dict with 4 keys:
#  - input_ids_chosen, attention_mask_chosen = tokenizer("A sentence that human labeler likes more")
#  - input_ids_rejected, attention_mask_rejected = tokenizer("A sentence that human labeler likes less")

#import torch
import datasets

class IMDBPairwiseDataset(torch.utils.data.Dataset):
    """ A dataset of all possible pairs of chosen and rejected texts in TRT reward training format """
    def __init__(self, imdb, tokenizer, accepted_label: int):
        super().__init__()
        self.tokenizer = tokenizer
        self.chosen_texts = [row['text'] for row in imdb if row['label'] == accepted_label]
        self.rejected_texts = [row['text'] for row in imdb if row['label'] != accepted_label]

        assert self.chosen_texts, f"no texts with label {accepted_label}"

        print(f"Found {len(self.chosen_texts)} chosen and {len(self.rejected_texts)} rejected texts, {len(self)} pairs")

        # Add column_names attribute for compatibility
        self.column_names = [
            "input_ids_chosen",
            "attention_mask_chosen",
            "input_ids_rejected",
            "attention_mask_rejected"
        ]

    def __len__(self):
        return len(self.chosen_texts) * len(self.rejected_texts)

    def __getitem__(self, index: int):
        chosen = self.tokenizer(
            self.chosen_texts[index // len(self.chosen_texts)],
            truncation=True,
            padding="max_length",
            max_length=512,
            return_tensors="pt"
        )

        rejected = self.tokenizer(
            self.rejected_texts[index % len(self.rejected_texts)],
            truncation=True,
            padding="max_length",
            max_length=512,
            return_tensors="pt"
        )

        return {
            "input_ids_chosen": chosen["input_ids"].squeeze(),
            "attention_mask_chosen": chosen["attention_mask"].squeeze(),
            "input_ids_rejected": rejected["input_ids"].squeeze(),
            "attention_mask_rejected": rejected["attention_mask"].squeeze(),
        }

# %%
TARGET_LABEL = 1 #<YOUR CHOICE - either 0 or 1>   # and make sure it works by reviewing the sample printed below
imdb = datasets.load_dataset("imdb", split='train')
reward_data = IMDBPairwiseDataset(imdb, reward_tokenizer, accepted_label=TARGET_LABEL)

sample = reward_data[31337]
print('CHOSEN:', reward_tokenizer.decode(sample['input_ids_chosen']))
print('REJECTED:', reward_tokenizer.decode(sample['input_ids_rejected']))
# Out:
# Found 12500 chosen and 12500 rejected texts, 156250000 pairs
# CHOSEN: [CLS] Lars Von Trier is never backward in trying out new techniques. Some of them are very original while others are best forgotten. < br / > < br / > He depicts postwar Germany as a nightmarish train journey. With so many cities lying in ruins, Leo Kessler a young American of German descent feels obliged to help in their restoration. It is not a simple task as he quickly finds out. < br / > < br / > His uncle finds him a job as a night conductor on the Zentropa Railway Line. His job is to attend to the needs of the passengers. When the shoes are polished a chalk mark is made on the soles. A terrible argument ensues when a passenger ' s shoes are not chalked despite the fact they have been polished. There are many allusions to the German fanaticism of adherence to such stupid details. < br / > < br / > The railway journey is like an allegory representing man ' s procession through life with all its trials and tribulations. In one sequence Leo dashes through the back carriages to discover them filled with half - starved bodies appearing to have just escaped from Auschwitz. These images, horrible as they are, are fleeting as in a dream, each with its own terrible impact yet unconnected. < br / > < br / > At a station called Urmitz Leo jumps from the train with a parceled bomb. In view of many by - standers he connects the bomb to the underside of a carriage. He returns to his cabin and makes a connection to a time clock. Later he jumps from the train ( at high speed ) and lies in the cool grass on a river bank. Looking at the stars above he decides that his job is to build and not destroy. Subsequently as he sees the train approaching a giant bridge he runs at breakneck speed to board the train and stop the clock. If you care to analyse the situation it is a completely impossible task. Quite ridiculous in fact. It could only happen in a dream. < br / > < br / > It ' s strange how one remembers little details such as a row of cups hanging on hooks and rattling away with the swaying of the train. < br / > < br / > Despite the fact that this film is widely acclaimed, I prefer Lars Von Trier ' s later films ( Breaking the Waves and The Idiots ). The bomb scene described above really put me off. Perhaps I ' m a [SEP]
# REJECTED: [CLS] I saw this movie in 1979, I was 17 or 18, when it was released. The theater was perhaps 1 / 4 full when the movie started. Ten minutes into the movie me and the friend who went with me to see the film were the only two people in the theater. The movie was really weird and had no plot or reason to its script and people demanded their money back. We decided to stay for the ENTIRE movie.... why endure such torture??... here ' s why. We wanted to be true movie critics... to have a standard to base all other movies on it is hard to justify saying you have seen the best movie ( a 10 ) they always come up with something better. But, it is easy to be able to base all other movies off of the worst movie ever made ( and this is it... a 1 at best ). There may be other movies out there that truly qualify as a 1, but I have yet to see them. I now base all movies I see on a scale based on this worst.... I AM A TRUE MOVIE CRITIC... he he. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]

# %% [markdown]
# We'll be using `trl.RewardTrainer` - a special case of `transformers.Trainer` that you used in the past. `RewardTrainer` accepts the same format of training arguments (e.g. batch size, gradient checkpointing) as before, except that it trains the model for the pairwise reward objective from [the InstructGPT paper](https://arxiv.org/pdf/2203.02155.pdf):
#
# ![img](https://i.imgur.com/2JzNAPs.png)
#
# Note that the model itself does not score pairs: it processes chosen ($y_w$) and rejected ($y_l$) samples independently. To minimize this loss, the reward model needs to score chosen sample higher than the rejected one. Note that the formula also assumes some context $x$, which is useful for seq2seq tasks. In our case of movie reviews, $x$ is empty.

# %%
import datasets
from trl import RewardTrainer, RewardConfig
from transformers import DataCollatorWithPadding

# Define Dataset Class
class IMDBPairwiseDataset(torch.utils.data.Dataset):
    """ Creates a dataset of paired (chosen, rejected) texts for reward training. """
    def __init__(self, imdb, tokenizer, accepted_label: int):
        super().__init__()
        self.tokenizer = tokenizer
        self.chosen_texts = [row['text'] for row in imdb if row['label'] == accepted_label]
        self.rejected_texts = [row['text'] for row in imdb if row['label'] != accepted_label]

        assert self.chosen_texts, f"no texts with label {accepted_label}"
        print(f"Found {len(self.chosen_texts)} chosen and {len(self.rejected_texts)} rejected texts, {len(self)} pairs")

        # Add column_names attribute for RewardTrainer compatibility
        self.column_names = [
            "input_ids_chosen",
            "attention_mask_chosen",
            "input_ids_rejected",
            "attention_mask_rejected"
        ]

    def __len__(self):
        return min(len(self.chosen_texts), len(self.rejected_texts))

    def __getitem__(self, index: int):
        chosen_text = self.chosen_texts[index % len(self.chosen_texts)]
        rejected_text = self.rejected_texts[index % len(self.rejected_texts)]

        chosen_tokenized = self.tokenizer(chosen_text, truncation=True, padding="max_length", max_length=512, return_tensors="pt")
        rejected_tokenized = self.tokenizer(rejected_text, truncation=True, padding="max_length", max_length=512, return_tensors="pt")

        return {
            "input_ids_chosen": chosen_tokenized["input_ids"].squeeze(),
            "attention_mask_chosen": chosen_tokenized["attention_mask"].squeeze(),
            "input_ids_rejected": rejected_tokenized["input_ids"].squeeze(),
            "attention_mask_rejected": rejected_tokenized["attention_mask"].squeeze(),
        }

# Create Dataset
TARGET_LABEL = 1  # Change to 0 for negative reviews
reward_data = IMDBPairwiseDataset(imdb, reward_tokenizer, accepted_label=TARGET_LABEL)
# Sample check
sample = reward_data[31337]
print('CHOSEN:', reward_tokenizer.decode(sample['input_ids_chosen']))
print('REJECTED:', reward_tokenizer.decode(sample['input_ids_rejected']))
# Out:
# Found 12500 chosen and 12500 rejected texts, 12500 pairs
# CHOSEN: [CLS] This movie has some things that are pretty amazing. First, it is supposed to be based on a true story. That, in itself, is amazing that multiple tornadoes would hit the same town at night in the fall - in Nebraska. I wonder if the real town ' s name was close to " Blainsworth " ( which is the town ' s name in the movie ). There is an Ainsworth, Nebraska, but there is also a town that starts with Blains - something. < br / > < br / > It does show the slowest moving tornadoes on record in the the seen where the boys are in the house. On the other hand, the scene where the TV goes fuzzy is based in fact. Before Doppler radar and weather radio, we were taught that if you turned your TV to a particular channel ( not on cable ) and tuned the brightness just right, you could tell if there was a tornado coming. The problem was that by then you would be able to hear it. < br / > < br / > Since I know something about midwest tornadoes, it made this movie fun for me. I enjoy it more than Twister. I mean, give me a break - there is no way you could make it through and F5 by chaining yourself to a pipe in a well house. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# REJECTED: [CLS] I saw this movie in 1979, I was 17 or 18, when it was released. The theater was perhaps 1 / 4 full when the movie started. Ten minutes into the movie me and the friend who went with me to see the film were the only two people in the theater. The movie was really weird and had no plot or reason to its script and people demanded their money back. We decided to stay for the ENTIRE movie.... why endure such torture??... here ' s why. We wanted to be true movie critics... to have a standard to base all other movies on it is hard to justify saying you have seen the best movie ( a 10 ) they always come up with something better. But, it is easy to be able to base all other movies off of the worst movie ever made ( and this is it... a 1 at best ). There may be other movies out there that truly qualify as a 1, but I have yet to see them. I now base all movies I see on a scale based on this worst.... I AM A TRUE MOVIE CRITIC... he he. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]

# %%
# Define Data Collator (Handles Padding)
class RewardDataCollator:
    def __init__(self, tokenizer):
        self.tokenizer = tokenizer
        self.default_collator = DataCollatorWithPadding(tokenizer)

    def __call__(self, batch):
        batch_chosen = [{"input_ids": ex["input_ids_chosen"], "attention_mask": ex["attention_mask_chosen"]} for ex in batch]
        batch_rejected = [{"input_ids": ex["input_ids_rejected"], "attention_mask": ex["attention_mask_rejected"]} for ex in batch]

        collated_chosen = self.default_collator(batch_chosen)
        collated_rejected = self.default_collator(batch_rejected)

        return {
            "input_ids_chosen": collated_chosen["input_ids"],
            "attention_mask_chosen": collated_chosen["attention_mask"],
            "input_ids_rejected": collated_rejected["input_ids"],
            "attention_mask_rejected": collated_rejected["attention_mask"],
        }

data_collator = RewardDataCollator(reward_tokenizer)

# Define Training Arguments
training_args = RewardConfig(
    output_dir="reward_model",
    remove_unused_columns=False,
    per_device_train_batch_size=16,
    gradient_accumulation_steps=2,
    learning_rate=1e-5,
    max_steps=1000,
    logging_steps=50,
    gradient_checkpointing=True,
    gradient_checkpointing_kwargs={"use_reentrant": False},
    fp16=True if torch.cuda.is_available() else False,
    report_to="none"
)

# Train the Reward Model
trainer = RewardTrainer(
    model=reward_model,
    args=training_args,
    train_dataset=reward_data,
    data_collator=data_collator,  # Use custom collator instead of RewardDataProcessor
    peft_config=None
)

trainer.train()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#     <div>
#
#       <progress value='1000' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1000 06:03, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.521800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.187200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.142100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.123200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.094200</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.112600</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.105700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.079300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.058900</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.063300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.051800</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.061900</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.063100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.044300</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.035200</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.046400</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.029300</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.031200</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.038900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.030100</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1000, training_loss=0.09601989269256592, metrics={'train_runtime': 364.0001, 'train_samples_per_second': 87.912, 'train_steps_per_second': 2.747, 'total_flos': 0.0, 'train_loss': 0.09601989269256592, 'epoch': 2.557544757033248})

# %%
reward_model.gradient_checkpointing_disable()
reward_model.eval()
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): DistilBertSdpaAttention(
#             (dropout): Dropout(p=0, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0, inplace=False)
# )

# %% [markdown]
# ### Sanity-check the reward model (1 point)
#
# Let's check how our reward model performs.
#
# __Your task__ is to measure how often does your reward model can rank a pair of (chosen and rejected) reviews correctly. Please measure this separately for train data (`imdb`) and a separate test set loaded below.

# %%
for sample_index in 45, 16000:
  print('TEXT:', imdb[sample_index]['text'])
  inputs = reward_tokenizer(
      imdb[sample_index]['text'], truncation=True, return_tensors='pt').to(device)
  with torch.no_grad():
    reward = reward_model(**inputs).logits[0, 0].item()
    print("REWARD:", reward)
  print('LABEL:', imdb[sample_index]['label'])
  print()

# note: your reward model may produce different absolute rewards.
# This is fine as long as the rewards are ordered correctly (most of the time)
# Out:
# TEXT: This movie sucked. It really was a waste of my life. The acting was atrocious, the plot completely implausible. Long, long story short, these people get "terrorized" by this pathetic "crazed killer", but completely fail to fight back in any manner. And this is after they take a raft on a camping trip, with no gear, and show up at a campsite that is already assembled and completely stocked with food and clothes and the daughters headphones. Additionally, after their boat goes missing, they panic that they're stuck in the woods, but then the daughters boyfriend just shows up and they apparently never consider that they could just hike out of the woods like he did to get to them. Like I said, this movie sucks. A complete joke. Don't let your girlfriend talk you into watching it.
# REWARD: -4.74609375
# LABEL: 0
#
# TEXT: Good: Engaging cinematic firefights, great presentation, vehicles are actually fun to drive, fairly appealing multiplayer, faithful to the movie, and the list goes on.<br /><br />Bad: Main missions are a bit short.<br /><br />This game defines what a "good" third person shooter(not necessarily a spy-game) is. Great firefights carry on the story and make you want to complete EVERY single mission through, and unlock all the genuine bonuses the game has to offer. The hype this game had, was lived up to, and I personally think you should buy it, and hook up with a couple of friends and play this one. Loads of fun. <br /><br />The sound in this game, is a rip-roaring achievement from a few previous bond games, and firing a weapon, really feels like you're firing a weapon. It ties in with the aspect that you are a deadly and ruthless spy.<br /><br />All in all, this game makes you excited and satisfied after you make it through, and some multiplayer that can compete with the standards of the crafty James Bond "Nightfire" game for gamecube.
# REWARD: 5.23828125
# LABEL: 1

# %%
imdb_test = datasets.load_dataset("imdb", split='test')

# %%
imdb_test[24999]
# Out:
# {'text': 'I caught this movie on the Sci-Fi channel recently. It actually turned out to be pretty decent as far as B-list horror/suspense films go. Two guys (one naive and one loud mouthed a**) take a road trip to stop a wedding but have the worst possible luck when a maniac in a freaky, make-shift tank/truck hybrid decides to play cat-and-mouse with them. Things are further complicated when they pick up a ridiculously whorish hitchhiker. What makes this film unique is that the combination of comedy and terror actually work in this movie, unlike so many others. The two guys are likable enough and there are some good chase/suspense scenes. Nice pacing and comic timing make this movie more than passable for the horror/slasher buff. Definitely worth checking out.',
#  'label': 1}

# %%
correct_predictions = 0
for sample_index in range(len(imdb_test)):
  inputs = reward_tokenizer(
      imdb_test[sample_index]['text'], truncation=True, return_tensors='pt').to(device)
  with torch.no_grad():
    reward = reward_model(**inputs).logits[0, 0].item()
#     print(reward, imdb_test[sample_index]['label'])
    if (reward < 0 and imdb_test[sample_index]['label'] == 0) or (reward >= 0 and imdb_test[sample_index]['label'] == 1):
        correct_predictions += 1
print('Accuracy on imdb_test = ', correct_predictions / len(imdb_test))
# Out:
# Accuracy on imdb_test =  0.91344

# %%
correct_predictions = 0
for sample_index in range(len(imdb)):
    inputs = reward_tokenizer(
      imdb[sample_index]['text'], truncation=True, return_tensors='pt').to(device)
    with torch.no_grad():
        reward = reward_model(**inputs).logits[0, 0].item()
        if (reward < 0 and imdb[sample_index]['label'] == 0) or (reward >= 0 and imdb[sample_index]['label'] == 1):
            correct_predictions += 1
print('Accuracy on imdb_train = ', correct_predictions / len(imdb))
# Out:
# Accuracy on imdb_train =  0.93508

# %% [markdown]
# ### Reward-guided generation (8 points)
#
# If you did everything right, by now you should have a decent reward model. Before we use it for reinforcement learning, let's see if we can align model samples without any training.
#
# To do so, you can use reward-guided inference: __generate N=16 samples, then select the one with the highest reward__ (according to your reward model).
#
# For this problem, it's on you to demonstrate whether or not your code works. Find at least 5 neutral prompts such as "This movie is" (...), "It was" (...), "I'd like to say", generate samples, rank them based on reward and show which samples get the highest reward.
#
# Note: it is faster to generate samples in parallel, rather than sequentially, as follows:

# %%
inputs = main_tokenizer(["It was"] * 5, return_tensors='pt').to(device)
for candidate in main_model.generate(**inputs, max_new_tokens=50, do_sample=True):
    print("Sample:", main_tokenizer.decode(candidate.flatten().cpu().numpy().tolist()))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample: It was interesting seeing the same team from the previous year as they had the same problems.<br /><br />This was the first time I felt this much sympathy for them. Then again you get the drift of the series. The series is so predictable and
# Sample: It was like sitting around with the dog - the dog walked around, ran, and never came back. When we finally came back to the house, I was so scared we didn't even know what to do." She remembers this as someone who tried repeatedly in
# Sample: It was supposed to be the story (about a beautiful young woman who kills herself for no apparent reason, etc.) but it wasn't in the actual movie, nor the story. Just in my opinion the best thing about the movie is that it didn't really
# Sample: It was too much for me after I read the reviews, and what I have to say is, that the movie was a good idea - and actually it got a lot of "comparable" movies on a level. But overall, the movie is too dull
# Sample: It was good that the movie was based on actual facts. I guess the truth is, the actual fact that everyone in North America was white at the time is nothing new. But if you don't know something about the story or can't see it coming,

# %%
from collections import defaultdict
import torch


# Define a list of at least 5 neutral prompts.
neutral_prompts = [
    "This movie is",
    "It was",
    "I'd like to say",
    "I felt that",
    "The film shows"
]

results = defaultdict(list)

# Iterate over each prompt
for prompt in neutral_prompts:
    # Tokenize the prompt for the main model (assuming main_tokenizer and main_model are defined)
    inputs = main_tokenizer([prompt] * 5, return_tensors="pt").to(device)

    # Generate 16 candidate responses in parallel.
    # Adjust max_new_tokens as appropriate for your task.
    candidate_ids = main_model.generate(
        **inputs,
        max_new_tokens=50,
        do_sample=True,
        num_return_sequences=16,
        top_k=0,         # Optionally adjust sampling parameters
        top_p=1.0
    )

    # Decode generated candidate responses into text.
    candidates = [
        main_tokenizer.decode(candidate.flatten().cpu().numpy().tolist())
        for candidate in candidate_ids
    ]

    # Compute the rewards for all candidate responses using your reward model.
    # compute_reward is a function you defined earlier that returns a tensor of rewards.
    # print(prompt)
    print(f"Prompt: {prompt}")
    for candidate in candidates:
        print(f"Candidate:{candidate}")

        inputs = reward_tokenizer(candidate, truncation=True, return_tensors="pt").to(device)
        with torch.no_grad():
            reward = reward_model(**inputs).logits[0,0].item()
            results[prompt].append(reward)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Prompt: This movie is
# Candidate:This movie is a prime example of such stupidity, which should never be exploited for fame, even as unconventional ideas, posited with plots loosely based on other characters, are doomed to fail, and even more undermined by ill-timed camera tricks.<br /><
# Candidate:This movie is obviously directed by Ray Liotta who did a great job in his role as an expectant father, clearly having successfully demonstrated how the comedic effects worked in this genre. While I went from the role of the madman into the role of somebody more sympathetic
# Candidate:This movie is also a cool one, which led me to make a 3, though not a 1.5.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Candidate:This movie is told through flashback, usually in flashback-only. Something about it would cement all the inconsistencies between our voice-overs, just to see the flashbacks. I don't see what it is that forcing us to flashback to a play instead of to us in
# Candidate:This movie is clichéd comedies on how to suck anti-heroes into interesting arguments about his place in the world.<br /><br />And sometimes humor feels like reading a fatard. Besides that, sadly, this bad guy you see becoming more and
# Candidate:This movie is so simple and so genuinely charming, and you can stand till the end with your hopes dashed, right away. From the script to the acting, real work. We never get distracted by anything else. a big sweet silver motif in but iting w
# Candidate:This movie is so absolutely pathetic that you trying to understand how all of it passed. It takes a star to check out the finale, and there are so many lame, light times-ghostly scenes, you can really't help but regret reading 'Indian Way'
# Candidate:This movie is hysterical. Bad acting, bad spoken instructions, bad direction, bad leading, bad lighting, bad script, weird mumbo jumbo, crazy special effects, bad editing. The script is very vague. Drink your tea. The plot is Earth is being
# Candidate:This movie is full of great laughs. But the acting, acting, directing and writing are hardly passable. Many people wonder when this is coming to DVD, because it even has reviews from critics. A paucity of modern children's films featuring all manner of
# Candidate:This movie is just unbelievable. Now that I've spent some time with the little brother I hope our future wait for us...If I'm going to convey what happened to him and what he missed, the last 10 years has already the worst movie.<br /><
# Candidate:This movie is sorry it could die at such a time it could have been rescued,they never did live in the same building and all the assets had been wiped out 80 years ago. not a good reason to see a sequel!<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Candidate:This movie is NOT for the faint of heart. I don't mean that I'm a admirer of Bogart Anthropological garbage, it falls into common-sucked-deep down areas of bizarre-enough-to-be-dramatic rubbish.OK
# Candidate:This movie is one of those can't-miss junkies that has no plot, and picks out a scene to shock your friends, sometimes topping which one anyway.<br /><br />The fun character focuses mostly on Boatman's relationship with himself which is a
# Candidate:This movie is moved like two people who require s.o.d. together, a tree falling from the sky and a tree coming.<br /><br />My wife and I are both 10 years older and i still smoked pot in high school - but now
# Candidate:This movie is shot as a 'white cap' of a highland with a good view of Spain. The charm of the film is lost when I witness the end of-scene scenes, from which my brain simply breaks jittery.<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>
# Candidate:This movie
# Candidate:The film shows young black boys playing catch-up with whites too much for them, namely Max, Daymail, an older generation of suburban teenagers who are no longer buying into the "American" belief that the "big category" citizens were in fact the "Big
# Candidate:The film shows "demon" makeup in the version thru the six year that we see in the make-up. Warlock Logan was butprised where the film was set, since there are some recognizable people and some that was made into things. But other than that
# Candidate:The film shows only the voices of Tong and He-Man well. The story certainly showed the maker Ming sayling Him, he also aired a band of his avid disciples. So long as all the actors were Hong Kong actors and directors, there make one guess how
# Candidate:The film shows Joe torturing people in order to get them to commit acts: getting drunk on their own father's wife, knifing his brother-in-law, stealing their guns, throwing a burning poker in the backyard of their argument-alike home
# Candidate:The film shows us models in various poses in a gavel, floor and curtain – all of which slimy, and some of them mask up.<br /><br />I have never seen a film so untamed and mysterious in its origins which feels in my
# Candidate:The film shows Gosling and James Hattie participating in a sex sting, as hillbillies and men. This killed a lot of the suspense. I liked the extreme gore angle. I, just, it id take a lot of time to watch the real "
# Candidate:The film shows Gus more as a straight man. More of a heist criminal like Finley but much more a gangster. As a man you see more with Gus and his decrease as the movie goes along achieving his jalistic goals. They did a nice
# Candidate:The film shows a revolutionary leader and a young boy as they fall in love. Don't remember that, there's nothing revolutionary about the film. This wasn't long ago. One reads other comments that this was made on VHS and thought this version was rubbish but
# Candidate:The film shows a man with a problem: his own world is too peaceful and unhappy to present to people. He has suffered a joint of debilitating headaches and insomnia.<br /><br />This human error can be exploited to gain a better image of Peter Pan,

# %%
scores = []
for prompt in results.keys():
    print(f"{prompt} : {max(results[prompt])}")
    scores.append((prompt,max(results[prompt])))

best_prompt = sorted(scores, key=lambda x: x[1], reverse=True)[0]
print(f"\nThe best prompt is: '{best_prompt[0]}' with a score of {best_prompt[1]}" )
# Out:
# This movie is : 5.3203125
# It was : 5.27734375
# I'd like to say : 5.0078125
# I felt that : 4.93359375
# The film shows : 4.9296875
#
# The best prompt is: 'This movie is' with a score of 5.3203125

# %%
average_scores = []
for prompt in results.keys():
    print(f"{prompt} : {sum(results[prompt])/len(results[prompt])}")
    average_scores.append((prompt,sum(results[prompt])/len(results[prompt])))

best_prompt = sorted(average_scores, key=lambda x: x[1], reverse=True)[0]
print(f"\nThe best prompt is: '{best_prompt[0]}' with a score of {best_prompt[1]}" )
# Out:
# This movie is : -0.14887218475341796
# It was : 1.2091812133789062
# I'd like to say : 0.2993801116943359
# I felt that : 0.47047119140625
# The film shows : 1.0811046600341796
#
# The best prompt is: 'It was' with a score of 1.2091812133789062

# %% [markdown]
# ## The prompt 'This movie is' had a higher overall score for all of its candidates with a score of 5.320 while the prompt 'It was' had the highest average score for all of its candidates with a score of 1.209

# %% [markdown]
# # Fine-tune the main model with RL (FOR PROJECT)
#
#
# For this tutorial, we will optimize GPT2 to produce positive IMDB movie reviews using the reward model you trained above.
#
# Unlike supervised fine-tuning, RL allows model to generate it's own sentences on each training step. Then, it calculates the reward of those specific sentences, and finally, updates the model to increase the probability of sentences with high reward.
#
# Thus, each RLHF consists of three stages: __Rollout__, __Evaluation__ and __Update__
#
# <div style="text-align: center">
# <img src='https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/gpt2_bert_training.png' width='600'>
#
# The update stage depends on the specific RL algorithm. We'll be using Proximal Policy Optimization, or [PPO](https://arxiv.org/abs/1707.06347), similarly to what was used for InstructGPT.
#
# Before we run those 3 stages, however, we need to create a dataset of "queries" - partial reviews in our case.

# %%
import trl

# %%
import random

class LengthSampler:
    def __init__(self, min_length, max_length):
        self.min_length = min_length
        self.max_length = max_length

    def __call__(self):
        return random.randint(self.min_length, self.max_length)

sample_length = LengthSampler(2, 8)  # use the first 2-8 tokens as query

# %%
def select_query_and_tokenize(sample):
    query_ids = main_tokenizer.encode(sample["text"])[: sample_length()]
    sample["query"] = main_tokenizer.decode(query_ids)  # query is the only required column
    sample["input_ids"] = query_ids  # to avoid re-tokenizing later
    return sample  # we do not need the rest - it will be generated by the model

imdb_for_rlhf = imdb.filter(lambda row: len(row['text']) > 200, batched=False)
imdb_for_rlhf = imdb_for_rlhf.remove_columns(['label'])
imdb_for_rlhf = imdb_for_rlhf.map(select_query_and_tokenize, batched=False)
imdb_for_rlhf.set_format(type="torch")
# Out:
# Map:   0%|          | 0/24895 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1168 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# Next, let's prepare your reward model to predict rewards on whatever reviews were generated. Note that we use plaintext reviews because main model uses a different tokenizer from the reward model.

# %%
#!g2.1
from typing import List
def compute_reward(texts: List[str]) -> torch.Tensor:
  inputs = reward_tokenizer(texts, truncation=True, padding=True, return_tensors='pt').to(device)
  with torch.no_grad():
    return reward_model(**inputs).logits[:, 0]

# %%
#!g2.1
compute_reward([imdb[45]['text'], imdb[16000]['text']])  # test on human-written reviews
# Out:
# tensor([-4.6484,  4.9336], device='cuda:0')

# %% [markdown]
# Finally, we move to RL training. In this tutorial, we'll train LoRA adapters and not the full model.

# %%
#!g2.1
import peft
peft_config = peft.LoraConfig(
    task_type=peft.TaskType.CAUSAL_LM, r=32, lora_alpha=32, lora_dropout=0.0, inference_mode=False
)

# reload main model as AutoModelForCausalLMWithValueHead - with an extra head needed for PPO
main_tokenizer = transformers.AutoTokenizer.from_pretrained("lvwerra/gpt2-imdb")
main_tokenizer.pad_token = main_tokenizer.eos_token

main_model = trl.AutoModelForCausalLMWithValueHead.from_pretrained("lvwerra/gpt2-imdb", device_map=device)
main_model = peft.get_peft_model(main_model, peft_config, adapter_name='default')
main_model.print_trainable_parameters()
# Out:
# trainable params: 1,179,648 || all params: 125,620,225 || trainable%: 0.9391
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/layer.py:1768: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(

# %% [markdown]
# Same as before, trl has a special type of trainer that minimize PPO-specific pseudo-loss. You can read more on this trainer [here](https://huggingface.co/docs/trl/main/en/ppo_trainer).

# %%
#!g2.1
training_args = trl.PPOConfig(
    model_name=main_model.config._name_or_path,
    gradient_accumulation_steps=1,
    learning_rate=1.41e-5,
    batch_size=64,
    ppo_epochs=4,                 # PPO performs this many updates per training batch
)

ppo_trainer = trl.PPOTrainer(
    training_args, model=main_model.model, tokenizer=main_tokenizer,
    dataset=imdb_for_rlhf, data_collator=lambda data: dict((key, [d[key] for d in data]) for key in data[0])
)  # note: we pass main_model.model because PPOTrainer checks for one of several supported model types ...
# ... main_model.model is a model with adapters, which is supported. main_model itself is a wrapper that is not supported
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b65815fcaa35> in <cell line: 0>()
#       1 #!g2.1
# ----> 2 training_args = trl.PPOConfig(
#       3     model_name=main_model.config._name_or_path,
#       4     gradient_accumulation_steps=1,
#       5     learning_rate=1.41e-5,
#
# TypeError: PPOConfig.__init__() got an unexpected keyword argument 'model_name'

# %%
#!g2.1
from tqdm.auto import tqdm
max_steps = 50   # can be insufficient for some tasks - watch your learning curves
generation_kwargs = dict(
    min_length=-1, max_new_tokens=128, do_sample=True, top_k=0, top_p=1.0, pad_token_id=main_tokenizer.eos_token_id)
#                                  ^-- task-specific parameter!
with tqdm(enumerate(ppo_trainer.dataloader), total=max_steps) as progressbar:
  # note: ppo_trainer.dataloader is just a regular dataloader of queries, no RL-specific magic :)
  for epoch, batch in progressbar:
    if epoch >= max_steps:
        break

    # Rollout stage: generate continuations from batch queries using main_model
    response_tensors = ppo_trainer.generate(batch['input_ids'], **generation_kwargs)
    # ^-- list of tensors of token ids from main model tokenizer

    # de-tokenize responses to strings (since reward model uses a different tokenizer)
    batch["response"] = [main_tokenizer.decode(response.squeeze()) for response in response_tensors]
    # note: response_tensors already contain query tokens, so we don't need to add queries manually.
    # This may not be true for other tasks: check this manually by viewing batch["response"] and batch["query"]


    # Evaluation stage
    rewards = compute_reward(batch['response'])

    # Update stage
    stats = ppo_trainer.step(batch['input_ids'], response_tensors, list(rewards.split(1)))
    stats['rewards/mean'] = rewards.mean().item()

    print("-" * 30, 'STEP', epoch, '-' * 30)
    print(f'rewards/mean:\t{stats["rewards/mean"]:.9f}\t<---- average reward over this batch (higher=better, noisy)')
    print(f'ppo/returns/mean:\t{stats["ppo/returns/mean"]:.9f}\t<---- model-estimated average discounted reward')
    print(f'objective/kl:\t{stats["objective/kl"]:.9f}\t<---- how far we are from the original model (regularizer)')
    print()

    ppo_trainer.log_stats(stats, batch, list(rewards.split(1)))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# ------------------------------ STEP 0 ------------------------------
# rewards/mean:	-0.033458710	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.419863880	<---- model-estimated average discounted reward
# objective/kl:	0.000000000	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 1 ------------------------------
# rewards/mean:	0.278663635	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.253651321	<---- model-estimated average discounted reward
# objective/kl:	0.424308300	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 2 ------------------------------
# rewards/mean:	0.573652029	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	-0.073742464	<---- model-estimated average discounted reward
# objective/kl:	0.916751623	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 3 ------------------------------
# rewards/mean:	0.680272102	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.014293447	<---- model-estimated average discounted reward
# objective/kl:	1.611181498	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 4 ------------------------------
# rewards/mean:	0.637197495	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.117953703	<---- model-estimated average discounted reward
# objective/kl:	2.776535749	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 5 ------------------------------
# rewards/mean:	1.090905190	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.169604033	<---- model-estimated average discounted reward
# objective/kl:	3.811805725	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 6 ------------------------------
# rewards/mean:	1.654058456	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.348742217	<---- model-estimated average discounted reward
# objective/kl:	4.794001579	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 7 ------------------------------
# rewards/mean:	1.492575169	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.495564699	<---- model-estimated average discounted reward
# objective/kl:	5.485957146	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 8 ------------------------------
# rewards/mean:	2.335594177	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.842965126	<---- model-estimated average discounted reward
# objective/kl:	6.395464420	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 9 ------------------------------
# rewards/mean:	1.561879158	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.669689775	<---- model-estimated average discounted reward
# objective/kl:	6.702696323	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 10 ------------------------------
# rewards/mean:	2.590698481	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.993873358	<---- model-estimated average discounted reward
# objective/kl:	7.981188774	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 11 ------------------------------
# rewards/mean:	2.106279373	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	0.975338578	<---- model-estimated average discounted reward
# objective/kl:	7.828726768	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 12 ------------------------------
# rewards/mean:	2.388473511	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.095461369	<---- model-estimated average discounted reward
# objective/kl:	9.245917320	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 13 ------------------------------
# rewards/mean:	2.576652527	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.267282486	<---- model-estimated average discounted reward
# objective/kl:	9.062112808	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 14 ------------------------------
# rewards/mean:	2.509240627	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.300251245	<---- model-estimated average discounted reward
# objective/kl:	10.028444290	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 15 ------------------------------
# rewards/mean:	2.929592133	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.450162172	<---- model-estimated average discounted reward
# objective/kl:	9.795566559	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 16 ------------------------------
# rewards/mean:	2.296215773	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.360654354	<---- model-estimated average discounted reward
# objective/kl:	9.118740082	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 17 ------------------------------
# rewards/mean:	3.076555252	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.661263227	<---- model-estimated average discounted reward
# objective/kl:	9.311429977	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 18 ------------------------------
# rewards/mean:	2.517547607	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.610380411	<---- model-estimated average discounted reward
# objective/kl:	10.609040260	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 19 ------------------------------
# rewards/mean:	3.498115540	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.983959317	<---- model-estimated average discounted reward
# objective/kl:	11.616748810	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 20 ------------------------------
# rewards/mean:	3.006476402	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	1.935671329	<---- model-estimated average discounted reward
# objective/kl:	11.283543587	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 21 ------------------------------
# rewards/mean:	3.373206139	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.001257420	<---- model-estimated average discounted reward
# objective/kl:	13.147975922	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 22 ------------------------------
# rewards/mean:	3.395843506	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.090600014	<---- model-estimated average discounted reward
# objective/kl:	12.343813896	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 23 ------------------------------
# rewards/mean:	3.547855377	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.211441755	<---- model-estimated average discounted reward
# objective/kl:	12.460732460	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 24 ------------------------------
# rewards/mean:	3.668563843	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.232666731	<---- model-estimated average discounted reward
# objective/kl:	13.552862167	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 25 ------------------------------
# rewards/mean:	3.558746338	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.340235233	<---- model-estimated average discounted reward
# objective/kl:	12.332838058	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 26 ------------------------------
# rewards/mean:	4.116277695	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.485009670	<---- model-estimated average discounted reward
# objective/kl:	14.513065338	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 27 ------------------------------
# rewards/mean:	3.592343330	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.315751076	<---- model-estimated average discounted reward
# objective/kl:	14.873290062	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 28 ------------------------------
# rewards/mean:	4.258361816	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.629878521	<---- model-estimated average discounted reward
# objective/kl:	14.515798569	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 29 ------------------------------
# rewards/mean:	3.839004517	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.503781319	<---- model-estimated average discounted reward
# objective/kl:	14.475437164	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 30 ------------------------------
# rewards/mean:	4.268234253	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.806118488	<---- model-estimated average discounted reward
# objective/kl:	13.404888153	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 31 ------------------------------
# rewards/mean:	4.048920155	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.651010036	<---- model-estimated average discounted reward
# objective/kl:	14.467522621	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 32 ------------------------------
# rewards/mean:	3.393676758	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.499082088	<---- model-estimated average discounted reward
# objective/kl:	15.021280289	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 33 ------------------------------
# rewards/mean:	3.963635921	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.690418243	<---- model-estimated average discounted reward
# objective/kl:	13.968084335	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 34 ------------------------------
# rewards/mean:	4.075362682	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.754722118	<---- model-estimated average discounted reward
# objective/kl:	15.962810516	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 35 ------------------------------
# rewards/mean:	4.204570770	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.755409241	<---- model-estimated average discounted reward
# objective/kl:	16.192779541	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 36 ------------------------------
# rewards/mean:	4.112086296	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.734297276	<---- model-estimated average discounted reward
# objective/kl:	15.588475227	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 37 ------------------------------
# rewards/mean:	4.101501465	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.744776249	<---- model-estimated average discounted reward
# objective/kl:	15.384011269	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 38 ------------------------------
# rewards/mean:	4.490764618	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.849191666	<---- model-estimated average discounted reward
# objective/kl:	17.840660095	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 39 ------------------------------
# rewards/mean:	4.198875427	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.791370392	<---- model-estimated average discounted reward
# objective/kl:	16.089687347	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 40 ------------------------------
# rewards/mean:	4.316064835	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.717653275	<---- model-estimated average discounted reward
# objective/kl:	15.130897522	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 41 ------------------------------
# rewards/mean:	4.028503418	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.756909847	<---- model-estimated average discounted reward
# objective/kl:	15.464221001	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 42 ------------------------------
# rewards/mean:	4.519897461	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.827311993	<---- model-estimated average discounted reward
# objective/kl:	17.389547348	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 43 ------------------------------
# rewards/mean:	3.798522949	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.683984756	<---- model-estimated average discounted reward
# objective/kl:	14.894588470	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 44 ------------------------------
# rewards/mean:	4.409133911	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.695876598	<---- model-estimated average discounted reward
# objective/kl:	15.236425400	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 45 ------------------------------
# rewards/mean:	4.256340027	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.821741581	<---- model-estimated average discounted reward
# objective/kl:	15.233748436	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 46 ------------------------------
# rewards/mean:	4.467102051	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.964675903	<---- model-estimated average discounted reward
# objective/kl:	15.735445023	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 47 ------------------------------
# rewards/mean:	3.935731888	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.648492575	<---- model-estimated average discounted reward
# objective/kl:	14.590065002	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 48 ------------------------------
# rewards/mean:	3.884203911	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.771272421	<---- model-estimated average discounted reward
# objective/kl:	14.206766129	<---- how far we are from the original model (regularizer)
#
# ------------------------------ STEP 49 ------------------------------
# rewards/mean:	4.287136078	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.812275410	<---- model-estimated average discounted reward
# objective/kl:	15.256341934	<---- how far we are from the original model (regularizer)

# %%
#!g2.1
print("-" * 30, 'STEP', epoch, '-' * 30)
print(f'rewards/mean:\t{stats["rewards/mean"]:.9f}\t<---- average reward over this batch (higher=better, noisy)')
print(f'ppo/returns/mean:\t{stats["ppo/returns/mean"]:.9f}\t<---- model-estimated average discounted reward')
print(f'objective/kl:\t{stats["objective/kl"]:.9f}\t<---- how far we are from the original model (regularizer)')
print()
# Out:
# ------------------------------ STEP 50 ------------------------------
# rewards/mean:	4.287136078	<---- average reward over this batch (higher=better, noisy)
# ppo/returns/mean:	2.812275410	<---- model-estimated average discounted reward
# objective/kl:	15.256341934	<---- how far we are from the original model (regularizer)

# %% [markdown]
# ## Main assignment - <u>actually</u> train the model
#
#
# Your main task for this week is to use the RLHF pipeline to train a model for a reward of your choice. Here's what you can choose from:
#
# __A. Toxicity fine-tuning:__ train the model to be less (or more!) toxic. For this task, you may use the data from [jigsaw toxic comments](https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge) and [lmsys/toxic-chat](https://huggingface.co/datasets/lmsys/toxic-chat),  or any other source. Alternatively, you may use toxicity scores from [oasst1](https://huggingface.co/datasets/OpenAssistant/oasst1).
#
#
# __B. Actual human feedback:__ use one of the existing datasets with pairwise human feedback to align your langauge model. You may use [anthropic's hh-rlhf](https://huggingface.co/datasets/Anthropic/hh-rlhf), [OpenAssistant dataset](https://huggingface.co/datasets/OpenAssistant/oasst1) or any other data you see fit. You may also turn the tables and train the model to [minimize](https://habrastorage.org/getpro/geektimes/post_images/ac7/2ad/827/ac72ad82767d4132164a4b6b76196c42.jpg) human preferences, as long as your model does not degrade to gibberish.
#
# __C. Controlled generation:__ Instead of training a reward model from human feedback, you may define the reward function as the text length (longer or shorter) or number of times the model uses specific words (e.g. "sorry", "apologize"). If you choose specific words, make sure the model generates them at least sometimes.
#
# __Alternatively,__ you may choose a different task. However, unless your task is very similar to one of the above, there is a chance that it will be **significantly** harder to solve, requiring orders of magnitude more compute and tuning. If you are in doubt, please ask the course staff. If they are AFK (again >.<), please prefer one of the recommended tasks.
#
#
# #### General tips & tricks
#
#
# Things to look out for:
# - during PPO stage, the reward model should be in eval mode (dropout disabled)
# - make sure max_length and max_new_tokens are enough for your chosen dataset - at least most of the time
# - when in doubt, view the data manually or inspect how the model performs on a few samples
#
#
# We highly recommend that you manually check the performance after each sub-stage:
# 1. when you assembled the pairwise dataset, inspect a couple of from of *your* dataset class and detokenize them. Make sure that you-the-human understand why one sample was accepted and the other - rejected. At least most of the time. This also lets you spot tokenization/truncation errors.
# 2. after you trained a reward model, measure how accurate this model is in isolation. If your reward model is poor, any subsequent RLHF will also fail.
# 3. once you've trained the main model with RL, ask it to generate examples and explore how well it does. If it produces an obviously bad output, check if the reward model assigns high reward to that output. If yes, reward model is the culprit; if no, it's a question of better/longer PPO training.
#
# __It is also a good idea to periodically print samples during training.__
#
# __When stuck, simplify the problem.__ If you've spent a several hours enchanting the reward model but it still won't budge, try switching to a simple subtask. For instance, if you're training on hh-rlhf, try limiting it the dataset to 10% of the shortest sequences - they are typically easier to learn.
#
#
# ## Assignment stages (and grading)
#
# Regardless of the specific task you chose, your solution needs to contain several parts that will be graded separately.
#
#
# #### Stage 1: reward model
#
# Construct a dataset for training the reward model on your problem. Then, train a reward model on that dataset and evaluate how well can your model predict preferences on a hold-out (test) subset of your data.
#
# Please make sure that the part of your notebook where you evaluate reward model is clearly visible and reasonably easy to read. And for all that is holy, do not call it IMDB unless it actually **is** data of imdb movie reviews :)
#
# __Not all tasks require a reward model for later PPO fine-tuning.__ For instance, there's no reason to train a reward model if your reward equals sentence length. Likewise, toxicity reward can be estimated with a pre-trained toxicity classifier. __If your task does not require training a reward model, please train an unrelated model on [hh-rlhf](https://huggingface.co/datasets/Anthropic/hh-rlhf) as though you were solving assignment version B.__ This is for grading purposes only, you won't use this model for stage 2.
#
#
# #### Stage 2: RL fine-tuning
#
# Once the reward model is ready - or you can compute rewards without a model - it is time to maximize that reward with PPO. Optionally, you may replace PPO with another RL algorithm (or unlikelihood learning scheme), but only if you're feeling adventurous.
#
#
# First, you need to choose a language model to be fine-tuned. You may choose any model, but make sure that your model **can** generate the data in your format. For instance, [Mistral-7B](https://huggingface.co/mistralai/Mistral-7B-v0.1) is a general purpose LM and may (or may not) need prompt engineering to generate chat assistant responses. For that reason, it is best if you **do not use `"lvwerra/gpt2-imdb"` unless you're generating only movie reviews**.
#
#
#
# There are two "difficulty modes" for this task:
# For the **easy mode**, use [gpt2-large](https://huggingface.co/gpt2-large) or [opt-1.3b](https://huggingface.co/facebook/opt-1.3b) with minimal code changes.
# If you want the **Hard mode:** use a larger (e.g. 7B) model in combination with `load_in_4bit` and LoRA, the same way we did last week.
# Some reasonable model choices are [LLaMA-7B](https://huggingface.co/Enoch/llama-7b-hf), [Falcon-7b](https://huggingface.co/tiiuae/falcon-7b), [Mistral-7B](https://huggingface.co/mistralai/Mistral-7B-v0.1) for general-purpose LM or [guanaco-7b](https://huggingface.co/timdettmers/guanaco-7b), [vicuna-7b](https://huggingface.co/lmsys/vicuna-7b-v1.5) for chat-based tasks, though there are many more (see [leaderboard](https://huggingface.co/spaces/HuggingFaceH4/open_llm_leaderboard)). In the hard mode, you will need to modify the training arguments to enable 4-bit fine-tuning. Furthermore, your experiments will take somewhat longer to complete. On the plus side, your model will produce significantly better results.
#
# __High reward is not enough!__ RL algorithms are famous for [cheating their reward functions](https://openai.com/research/faulty-reward-functions). To ensure that your model is actually doing what you want it to do, you will need some additional evaluation. To get the full grade, provide at least 20 side-by-side examples of your fine-tuned model vs original model predictions and a short summary.
#
# Alternatively, you may provide 5 examples and some extrinsic evaluation metric over many examples. For instance, you may use a different pre-trained toxicity score for option A. When dealing with human preferences, you may choose to [enlist actual humans](https://toloka.ai/) or [ask GPT4/Claude](https://arxiv.org/pdf/2304.03277.pdf) to compare your model's predictions. For task C, when optimizing for simple rewards like sentence lengths, it is enough to compare histograms of rewards (e.g. average lengths).
